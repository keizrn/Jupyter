# %% [markdown]
# ## Задание 1
# 1. Скачать данные по ссылке https://www.kaggle.com/datasets/ionaskel/laptop-prices
# 2. Считать данные с помощью pandas
# 3. Вывести на экран первые 5 строк
# 4. Посмотреть на описание признаков и на их содержание

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./laptop_price.csv', encoding='latin-1')
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df.head()
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# ...

# %%
df.describe()
# Out:
#          laptop_ID       Inches  Price_euros
# count  1303.000000  1303.000000  1303.000000
# mean    660.155794    15.017191  1123.686992
# std     381.172104     1.426304   699.009043
# min       1.000000    10.100000   174.000000
# 25%     331.500000    14.000000   599.000000
# 50%     659.000000    15.600000   977.000000
# 75%     990.500000    15.600000  1487.880000
# max    1320.000000    18.400000  6099.000000

# %%
df.shape
# Out:
# (1303, 13)

# %% [markdown]
# ## Задание 2
# Проведите первичный анализ данных
# 1. Изучите типы данных
# 2. Найдите количество пропущенных ячеек в данных
# 3. Посчитайте основные статистики по всем признакам и поизучайте их

# %%
df.dtypes
# Out:
# laptop_ID             int64
# Company              object
# Product              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price_euros         float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df.describe(include='all')
# Out:
#           laptop_ID Company Product  TypeName       Inches   ScreenResolution  \
# count   1303.000000    1303    1303      1303  1303.000000               1303
# unique          NaN      19     618         6          NaN                 40
# top             NaN    Dell  XPS 13  Notebook          NaN  Full HD 1920x1080
# freq            NaN     297      30       727          NaN                507
# mean     660.155794     NaN     NaN       NaN    15.017191                NaN
# std      381.172104     NaN     NaN       NaN     1.426304                NaN
# min        1.000000     NaN     NaN       NaN    10.100000                NaN
# 25%      331.500000     NaN     NaN       NaN    14.000000                NaN
# 50%      659.000000     NaN     NaN       NaN    15.600000                NaN
# 75%      990.500000     NaN     NaN       NaN    15.600000                NaN
# max     1320.000000     NaN     NaN       NaN    18.400000                NaN
#
# ...

# %% [markdown]
# ## Задание 3
# Ответьте на несколько вопросов
# ### 3.1 Ноутбуков от какой компании больше всего в наборе данных?
# ```Смотрим на строку Top - Dell
# На самом деле нет...```

# %%
df.Company.value_counts()
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
df.Company.mode()
# Out:
# 0      Dell
# 1    Lenovo
# Name: Company, dtype: object

# %% [markdown]
# ### 3.2 Какая минимальная и максимальная стоимость у ноутбуков в данных?
# ```Смотрим на колонку Price_euros. Min = 174, Max = 6099```

# %%
min(df.Price_euros), max(df.Price_euros)
# Out:
# (174.0, 6099.0)

# %% [markdown]
# ### 3.3 Какой самый дорогой ноутбук в данных?
# Выведите все характеристики только по этому ноутбуку
#
# Если таких ноутбуков несколько, то выводите их всех

# %%
expen = df[df.Price_euros == max(df.Price_euros)]
expen
# Out:
#      laptop_ID Company    Product TypeName  Inches  \
# 196        200   Razer  Blade Pro   Gaming    17.3
#
#                         ScreenResolution                          Cpu   Ram  \
# 196  4K Ultra HD / Touchscreen 3840x2160  Intel Core i7 7820HK 2.9GHz  32GB
#
#       Memory                      Gpu       OpSys  Weight  Price_euros
# 196  1TB SSD  Nvidia GeForce GTX 1080  Windows 10  3.49kg       6099.0

# %% [markdown]
# ## Задание 4
# Ответьте на несколько вопросов
# ### 4.1 Найдите ноутбуки с самой маленькой диагональю в данных?
# Выведите только следующие характеристики:
# - Компания
# - Тип ноутбука
# - Диагональ
# - Стоимость
#
# Если таких ноутбуков несколько, то выводите их всех

# %%
sm_diag = df[df.Inches == min(df.Inches)][['Company','TypeName', 'Inches', 'Price_euros']]
sm_diag
# Out:
#      Company            TypeName  Inches  Price_euros
# 50    Lenovo  2 in 1 Convertible    10.1       319.00
# 1082  Lenovo  2 in 1 Convertible    10.1       646.27
# 1114  Lenovo  2 in 1 Convertible    10.1       549.00
# 1126  Lenovo  2 in 1 Convertible    10.1       479.00

# %%
sm_diag2 = df.loc[df.Inches == min(df.Inches),['Company','TypeName', 'Inches', 'Price_euros']]
sm_diag2
# Out:
#      Company            TypeName  Inches  Price_euros
# 50    Lenovo  2 in 1 Convertible    10.1       319.00
# 1082  Lenovo  2 in 1 Convertible    10.1       646.27
# 1114  Lenovo  2 in 1 Convertible    10.1       549.00
# 1126  Lenovo  2 in 1 Convertible    10.1       479.00

# %% [markdown]
# ### 4.2 Сколько стоит самый дорогой ноутбук у компании HP?

# %%
df[df.Company == 'HP'].sort_values('Price_euros')
# Out:
#       laptop_ID Company            Product            TypeName  Inches  \
# 1268       1286      HP   Stream 11-Y000na             Netbook    11.6
# 1296       1314      HP   Stream 11-Y000na             Netbook    11.6
# 1282       1300      HP   Stream 11-Y000na             Netbook    11.6
# 67           69      HP  Stream 14-AX040wm            Notebook    14.0
# 1168       1186      HP  Stream 14-AX000nv            Notebook    14.0
# ...         ...     ...                ...                 ...     ...
# 857         868      HP     EliteBook x360  2 in 1 Convertible    13.3
# 1103       1118      HP           ZBook 17         Workstation    17.3
# 911         924      HP    Elitebook Folio           Ultrabook    12.5
# 1136       1151      HP           ZBook 17         Workstation    17.3
# 749         758      HP           Zbook 17         Workstation    17.3
#
#                          ScreenResolution  \
# 1268                             1366x768
# ...

# %%
max_price = max(df[df.Company == 'HP'].Price_euros)
exp_hp = df[(df.Company == 'HP') & (df.Price_euros == max_price)]
exp_hp
# Out:
#      laptop_ID Company   Product     TypeName  Inches  \
# 749        758      HP  Zbook 17  Workstation    17.3
#
#                 ScreenResolution                            Cpu   Ram  \
# 749  IPS Panel Full HD 1920x1080  Intel Xeon E3-1535M v5 2.9GHz  16GB
#
#         Memory                   Gpu      OpSys Weight  Price_euros
# 749  256GB SSD  Nvidia Quadro M2000M  Windows 7    3kg       4389.0

# %% [markdown]
# ### 4.3 Как много ноутбуков Ultrabook с 8GB RAM?
# Найдите сколько таких ультрабуков с 8GB ОЗУ в процентном соотношении относительно всех ультрабуков

# %%
df[(df.TypeName == 'Ultrabook') & (df.Ram == '8GB')]
# Out:
#       laptop_ID Company               Product   TypeName  Inches  \
# 0             1   Apple           MacBook Pro  Ultrabook    13.3
# 1             2   Apple           Macbook Air  Ultrabook    13.3
# 4             5   Apple           MacBook Pro  Ultrabook    13.3
# 7             8   Apple           Macbook Air  Ultrabook    13.3
# 9            10    Acer               Swift 3  Ultrabook    14.0
# ...         ...     ...                   ...        ...     ...
# 1236       1254      HP         EliteBook 840  Ultrabook    14.0
# 1241       1259    Asus  ZenBook UX310UA-WB71  Ultrabook    13.3
# 1261       1279    Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
# 1275       1293    Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
# 1289       1307    Asus  ZenBook UX305CA-UBM1  Ultrabook    13.3
#
#                         ScreenResolution                         Cpu  Ram  \
# 0     IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8GB
# ...

# %%
ultra = df[df.TypeName == 'Ultrabook']
ultra.Ram.value_counts(normalize=True)
# Out:
# 8GB     0.714286
# 16GB    0.183673
# 4GB     0.071429
# 12GB    0.015306
# 24GB    0.005102
# 32GB    0.005102
# 6GB     0.005102
# Name: Ram, dtype: float64

# %% [markdown]
# ## Задание 5
# ### 5.1 Выберите ноутбук клиенту
# Клиент хочет подобрать ноутбук с 8GB или 16GB ОЗУ на Windows 10 в стоимости до 500 евро, сколько у него вариантов?

# %%
sample1 = df[((df.Ram == '8GB') | (df.Ram == '16GB')) & (df.OpSys == 'Windows 10') & (df.Price_euros <= 500)]
sample1
# Out:
#       laptop_ID Company                                   Product  TypeName  \
# 74           76    Acer                             Aspire E5-475  Notebook
# 175         179    Dell                             Inspiron 3567  Notebook
# 256         261      HP        15-BW094nd (A6-9220/8GB/128GB/W10)  Notebook
# 292         297      HP         17-BS037cl (i3-6006U/8GB/1TB/W10)  Notebook
# 313         318    Acer  ES1-523-84K7 (A8-7410/8GB/256GB/FHD/W10)  Notebook
# 365         371      HP            15-AY023na (N3710/8GB/2TB/W10)  Notebook
# 571         578      HP            14-am079na (N3710/8GB/2TB/W10)  Notebook
# 595         602  Lenovo                         IdeaPad 110-15ISK  Notebook
# 634         642    Asus         X541NA-GO414T (N3350/8GB/1TB/W10)  Notebook
# 702         710  Lenovo                         IdeaPad 320-15ABR  Notebook
# 1057       1071    Acer                            Aspire ES1-523  Notebook
# ...

# %%
sample1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 74 to 1232
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         13 non-null     int64
#  1   Company           13 non-null     object
#  2   Product           13 non-null     object
#  3   TypeName          13 non-null     object
#  4   Inches            13 non-null     float64
#  5   ScreenResolution  13 non-null     object
#  6   Cpu               13 non-null     object
#  7   Ram               13 non-null     object
#  8   Memory            13 non-null     object
#  9   Gpu               13 non-null     object
#  10  OpSys             13 non-null     object
#  11  Weight            13 non-null     object
#  12  Price_euros       13 non-null     float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.4+ KB

# %%
sample1.shape[0]
# Out:
# 13

# %% [markdown]
# ```**Ответ:** 13```

# %% [markdown]
# ### 5.2 Выберите ноутбук клиенту
# Клиент хочет подобрать ноутбук от MSI, с видеокартой Nvidia GeForce GTX 1050 Ti и главное не с диагональю 15.6. В какой ценовой категории вышли подобные ноутбуки?

# %%
sample2 = df[(df.Company == 'MSI') & (df.Gpu == 'Nvidia GeForce GTX 1050 Ti') & ~(df.Inches == 15.6)]
sample2.sort_values('Price_euros')
# Out:
#       laptop_ID Company        Product TypeName  Inches   ScreenResolution  \
# 330         336     MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 724         732     MSI     GL72M 7REX   Gaming    17.3  Full HD 1920x1080
# 393         400     MSI  Leopard GP72M   Gaming    17.3  Full HD 1920x1080
# 1156       1174     MSI     GP72M 7REX   Gaming    17.3  Full HD 1920x1080
# 917         931     MSI     GE72VR 6RF   Gaming    17.3  Full HD 1920x1080
#
#                               Cpu   Ram                Memory  \
# 330   Intel Core i7 7700HQ 2.8GHz   8GB  256GB SSD +  1TB HDD
# 724   Intel Core i7 7700HQ 2.8GHz   8GB  128GB SSD +  1TB HDD
# 393   Intel Core i7 7700HQ 2.8GHz   8GB             256GB SSD
# 1156  Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
# 917   Intel Core i7 7700HQ 2.8GHz  16GB  256GB SSD +  1TB HDD
#
#                              Gpu       OpSys Weight  Price_euros
# 330   Nvidia GeForce GTX 1050 Ti  Windows 10  2.7kg      1199.00
# ...

# %%
min(sample2.Price_euros), max(sample2.Price_euros)
# Out:
# (1199.0, 1599.0)

# %% [markdown]
# ### 5.3 Что дешевле?
# В среднем дешевле ноутбуки с CPU Intel Core i7 7700HQ 2.8GHz или с Intel Core i7 7600U 2.8GHz?

# %%
sample3a = df[df.Cpu == 'Intel Core i7 7700HQ 2.8GHz']['Price_euros']
sample3b = df[df.Cpu == 'Intel Core i7 7600U 2.8GHz']['Price_euros']

# %%
sample3a.mean(), sample3b.mean()
# Out:
# (1760.4084246575337, 1915.710769230769)

# %% [markdown]
# ## Задание 6
# Найдите самый легкий ноутбук
#
# Но обратите внимание на тип и представление данных в признаке Weight, если что, замените в строке 'kg' на пустую строку через метод .str.replace()

# %%
df
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df[df.Weight.str.contains('kg')]
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df_w = df
df_w.Weight = df_w.Weight.str.replace('kg', '')

df_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
df_w
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
df_w.Weight = df_w.Weight.astype('float64')
df_w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   float64
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(3), int64(1), object(9)
# memory usage: 132.5+ KB

# %%
df_w[df_w.Weight == min(df_w.Weight)]
# Out:
#       laptop_ID Company    Product            TypeName  Inches  \
# 50           51  Lenovo  Yoga Book  2 in 1 Convertible    10.1
# 1082       1097  Lenovo  Yoga Book  2 in 1 Convertible    10.1
# 1114       1129  Lenovo  Yoga Book  2 in 1 Convertible    10.1
# 1126       1141  Lenovo  Yoga Book  2 in 1 Convertible    10.1
#
#                      ScreenResolution                          Cpu  Ram  \
# 50    IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
# 1082  IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
# 1114  IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
# 1126  IPS Panel Touchscreen 1920x1200  Intel Atom x5-Z8550 1.44GHz  4GB
#
#                   Memory                    Gpu       OpSys  Weight  \
# 50    64GB Flash Storage  Intel HD Graphics 400     Android    0.69
# 1082  64GB Flash Storage  Intel HD Graphics 400  Windows 10    0.69
# 1114  64GB Flash Storage  Intel HD Graphics 400     Android    0.69
# ...
