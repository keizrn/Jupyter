# %% [markdown]
# ## Задание 1
# ### 1.1 Соедините два словаря в один
# dict1 = {'One': 1, 'Two': 2, 'Three': 3}
#
# dict2 = {'Four': 4, 'Five': 5, 'Six': 6}
#
#
# ### 1.2 Напишите функцию, которая на вход принимает два словаря и возвращает один объединенный словарь
# Используйте аннотирование типов

# %%
dict1 = {'One': 1, 'Two': 2, 'Three': 3}
dict2 = {'Four': 4, 'Five': 5, 'Six': 6}

# %%
dict3 = dict1
dict3.update(dict2)
dict3
# Out:
# {'One': 1, 'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5, 'Six': 6}

# %%
def merge_2(dict_a: dict, dict_b: dict) -> dict:
    d_new = {**dict_a, **dict_b}
    return d_new

# %%
print(merge_2(dict1, dict2))
# Out:
# {'One': 1, 'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5, 'Six': 6}

# %%
def merge_3(dict_a: dict, dict_b: dict) -> dict:
    d_new = dict(dict_a, **dict_b)
    return d_new

print(merge_3(dict1, dict2))
# Out:
# {'One': 1, 'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5, 'Six': 6}

# %%
from collections import ChainMap

# %%
def merge_4(dict_a: dict, dict_b: dict) -> dict:
    d_new = dict(ChainMap(dict_a, dict_b))
    return d_new

print(merge_4(dict1, dict2))
# Out:
# {'Four': 4, 'Five': 5, 'Six': 6, 'One': 1, 'Two': 2, 'Three': 3}

# %%
def merge_5(dict_a: dict, dict_b: dict) -> dict:
    d_new = dict(dict_a | dict_b)
    return d_new

print(merge_5(dict1, dict2))
# Out:
# {'One': 1, 'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5, 'Six': 6}

# %% [markdown]
# ## Задание 2.
# Напишите функцию, которая из двух списков, делает один словарь, где элементы из первого списка - ключи, а элементы из второго списка - значения
#
# keys = ['One', 'Two', 'Three']
#
# values = [1, 2, 3]
#
# Используйте аннотирование типов
#
# ### 2.1 Используя цикл for
# ### 2.2 Используя dict comprehensions

# %%
keys = ['One', 'Two', 'Three']
values = [1, 2, 3]

# %%
def create_dict(keys: list, values: list) -> dict:
    if len(keys) != len(values):
        return None
    else:
        d1 = dict(zip(keys, values))
        return d1

print(create_dict(keys, values))
# Out:
# {'One': 1, 'Two': 2, 'Three': 3}

# %%
d2 = {keys[i]:values[i] for i in range(3)}
print(d2)
# Out:
# {'One': 1, 'Two': 2, 'Three': 3}

# %% [markdown]
# ## Задание 3.
#
# Извлеките только два ключа name и age из представленного словаря
#
#
# client_dict = {<br>
# 	&emsp;"name": "John",<br>
# 	&emsp;"age": 25,<br>
# 	&emsp;"salary": 5000,<br>
# 	&emsp;"city": "Moscow"<br>
# }
#
# ### 3.1 Напишите функцию с циклом for
# Функция на вход принимает:
# - исходный словарь
# - ключи, которые нужно извлечь (аргумент по умолчанию)
#
# На выходе словарь с нужными ключами
#
# Используйте аннотирование типов
#
# ### 3.2 Используя dict comprehensions

# %%
client_dict = {'name': 'John', 'age': 25, "salary": 5000, "city": "Moscow"}

# %%
def eliminate_dict(dict_c: dict) -> dict:
    dict_c2 = {}
    for key, value in dict_c.items():
        if key != 'name' and key != 'age':
            dict_c2.update({key: value})
    return dict_c2

print(eliminate_dict(client_dict))
# Out:
# {'salary': 5000, 'city': 'Moscow'}

# %%
d3 = {key: value for key, value in client_dict.items() if key != 'name' and key != 'age'}
d3
# Out:
# {'salary': 5000, 'city': 'Moscow'}

# %% [markdown]
# ## Задание 4.
#
# ### 4.1 Сгенерируйте случайные целые числа от 0 до 100 в количестве 5 штук с помощью модуля random
#
# - Зафиксируйте псевдогенерацию, чтобы сгенерированные значения всегда были одинаковые
# - Используйте list comprehensions

# %%
import random

# %%
list_4 = []
for i_4 in range(5):
    random.seed(a=20)
    list_4.append(random.randrange(0, 101))
print(list_4)
# Out:
# [92, 92, 92, 92, 92]

# %%
random.seed(a=20)
list_4a = [random.randrange(0, 101) for _ in range(5)]
list_4a
# Out:
# [92, 87, 100, 98, 19]

# %% [markdown]
# ## Задание 5.
# ### 5.1 Найдите картинку в интернете и прикрепите её в ячейку с текстом
# ### 5.2 Создайте следующую таблицу в ячейке с текстом
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# Красивая девушка:
#
# <img src="https://i.pinimg.com/originals/85/9b/e7/859be7e28a20322702006b93a1594aff.jpg" alt="Girl" width='300px'>

# %% [markdown]
# <table>
#     <tr>
#         <td></td>
#         <td>До события</td>
#         <td>После события</td>
#     </tr>
#     <tr>
#         <td>1 кт</td>
#         <td>50</td>
#         <td>350</td>
#     </tr>
# </table>

# %% [markdown]
# ## Задание 6.
#
# Напишите функцию, которая может принимать любое количество трат пользователя и считать сумму и среднее.
# - На вход поступают целочисленные значения в любом количестве
# - На выходе словарь с ключами суммы трат и средней траты

# %%
def sumandmean(*args) -> (int, int):
    return(sum(args), sum(args)/len(args))

sumandmean(5, 7, 8)
# Out:
# (20, 6.666666666666667)

# %%
sumandmean(6, 8)
# Out:
# (14, 7.0)

# %%
def sumandmean2(list2) -> (int, int):
    return(sum(list2), sum(list2)/len(list2))

sumandmean2(list(map(int, input('Введите аргументы через пробел\n').split())))
# Out:
# Введите аргументы через пробел
# 5 7 8
# (20, 6.666666666666667)
