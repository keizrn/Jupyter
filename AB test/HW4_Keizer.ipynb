# %% [markdown]
# # Домашнее задание 4
# ## A/B-тестирование мобильных приложений.
#
# Настроить а/б тест на сайте с 2-мя изменениями на своем сайте либо на аккаунте преподавателя(доступ по запросу).
#
# Уведомления:
# - remote config
# - in-app сообщения

# %% [markdown]
# ### Remote config:

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### in-app сообщения

# %% [markdown]
# https://console.firebase.google.com/project/gb-sem4/inappmessaging/compose?campaignId=4451056724131998925&view=true

# %% [markdown]
# ![image.png](attachment:image.png)
