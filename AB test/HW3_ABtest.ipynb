# %% [markdown]
# # Домашнее задание 3
# ## A/B-тестирование веб-приложений
#
# Настроить а/б тест на сайте с 3-мя изменениями https://telegram-feedback.com/ /личном сайте (доступ по запросу) https://english22.tilda.ws/

# %% [markdown]
# ### Выбираю сайт English22
#
# Будем считать, что это новый бизнес. Ключевые метрики будут связаны с привлечением и удержанием новых клиентов.
#
# Для простоты эксперимента будем считать метрику: Конверсия в покупку (бесплатного тестового периода обучения).
# Иными словами, количество пользователей, нажавших на кнопку "Попробовать бесплатно" от общего количества пользователей, посмотревших страницу.

# %% [markdown]
# ### Гипотеза. Пользователи предпочитают зеленую цветовую гамму. Изменение цветовой гаммы улучшит конверсию.
#
# **Действие:** Сделать сайт с зеленым цветом.
#
# **Тест-группа:** 20% посетителей страницы.
#
# **Метрика:** процент пользователей, нажавших на кнопку "Попробовать бесплатно".
#
# **План действий:** Если метрики в тестовой группе улучшаются относительно контрольной группы, запустить изменение дизайна с использованием зеленой цветовой гаммы.
#
#
# **Ссылка на Google Optimize:**
# https://optimize.google.com/optimize/home/?authuser=0&hl=en-US#/accounts/4705187983/containers/15531172/experiments/515

# %% [markdown]
# |Original|Variant B|
# |:---:|:---:|
# |![image.png](attachment:image.png)|![image-2.png](attachment:image-2.png)|
# |||
# |![image-6.png](attachment:image-6.png)|![image-5.png](attachment:image-5.png)|

# %% [markdown]
# ### Google Optimize:
# 14 цветовых изменений на странице в сторону использования зеленого цвета.
# Ограничение целевой аудитории - только город Москва. Любые устройства.
# ![image.png](attachment:image.png)
#
# ### Цели:
# 1. Увеличить количество кликов по кнопкам.
# 2. Дополнительно считаем встроенную конверсию.
# 3. Нам нужно знать количество просмотров в каждой из групп пользователей, чтобы правильно посчитать конверсию.
#
# ![image-4.png](attachment:image-4.png)
