# %% [markdown]
# ## Случайная величина
# ### Дискретная
# Принимает счетные, отдельные друг от друга значения
# ![image-3.png](attachment:image-3.png)
# ### Непрерывная
# Лежит в некотором интервале.
# Можем измерить с той точностью, что позволяет прибор или с той точностью, которая необходима.
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# ### Функция распределения вероятностей
# Функция F(x), которая для каждого значения x показывает, какова вероятность того, что случайная величина меньше или равна x.
# ![image-5.png](attachment:image-5.png)
#
# Плотность распределения вероятностей - это функция f(x), которая равна производной функции распределения вероятностей
# ![image-4.png](attachment:image-4.png)
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# ### Нормальное распределение (распределение Гаусса)
# Нормальное распределение - это распределение вероятностей  непрерывной случайной величины X, плотность вероятности которой   подчиняется формуле:
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### Свойства нормального распределения
# - Колоколообразная форма
# - График симметричен оси y
# - Площадь под дугой равна единице
# - Показывает долю (вероятность) СВ меньше 𝑥
# - Значения среднего, медианы и моды совпадают
# ![image-2.png](attachment:image-2.png)
#
# ### Правило трех сигм
# - На отрезке от −σ до +σ расположено около 68% наблюдений,
# - от −2σ до +2σ - 95.4%,
# - от −3σ до +3σ - 99.72 % наблюдений
# ![image-5.png](attachment:image-5.png)

# %% [markdown]
# ### Стандартное нормальное распределение
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Пример:
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# Ответ: 10.2% значений меньше, или равны, чем -1.27

# %% [markdown]
# ### Нормирование
# Если 𝑋~ 𝑁 (μ , 𝞼<sup>2</sup> ), тогда
# ![image-5.png](attachment:image-5.png)
#
# Пример: Диаметр гаек следует нормальному распределению с mu= 5 мм, дисперсией 0.36 мм2. Найти  пропорцию гаек с размером менее 3,78 мм
# ![image-3.png](attachment:image-3.png)

# %%
import numpy as np
import math

# %%
Z_norm = (3.78 - 5) / math.sqrt(0.36)
Z_norm
# Out:
# -2.0333333333333337

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Центральная предельная теорема
# Пусть генеральная совокупность имеет любое распределение с средним арифметическим μ и дисперсией 𝞂<sup>2</sup>, тогда:
#
# ![image-4.png](attachment:image-4.png)
#
# Распределение случайной величины X
# ![image-8.png](attachment:image-8.png)
#
# Распределение среднего арифметического выборки случайной величины Х
#
# 𝞼 /√𝑛 - стандартная ошибка среднего (SE)
# ![image-9.png](attachment:image-9.png)

# %% [markdown]
# ### Равномерное распределение
# Непрерывная случайная величина равномерно распределена на отрезке ab, если плотность распределения вероятностей ее равна нулю за пределами отрезка и равна постоянной величине внутри него.
#
# ![image-3.png](attachment:image-3.png)
#
# График плотности равномерного распределения
# ![image-4.png](attachment:image-4.png)
#
# Вероятность P попадания величины 𝑥 в интервал между 𝑎 и 𝑏 равна площади под графиком функции плотности вероятностей 𝑓(𝑥)
# ![image-7.png](attachment:image-7.png)
#
# График функции равномерного распределения
# ![image-10.png](attachment:image-10.png)
# ![image-9.png](attachment:image-9.png)
#
# ![image-11.png](attachment:image-11.png)

# %% [markdown]
# #### Пример задачи
# Найти математическое ожидание и дисперсию равномерно распределенной величины на отрезке от 2 до 8

# %%
Ev_2 = (2 + 8) / 2
Ev_2
# Out:
# 5.0

# %%
D_2 = (8 - 2)**2 / 12
D_2
# Out:
# 3.0

# %% [markdown]
# ### Другие непрерывные распределения
# 1. Экспоненциальное
# 2. Распределение Фишера
# 3. Хи-квадрат
# 4. Распределение Колмогорова
#
# ![%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-03-15%20142322.jpg](attachment:%D0%A1%D0%BD%D0%B8%D0%BC%D0%BE%D0%BA%20%D1%8D%D0%BA%D1%80%D0%B0%D0%BD%D0%B0%202023-03-15%20142322.jpg)
